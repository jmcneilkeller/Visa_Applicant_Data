# %% [markdown]
# # Mod3 Project Data Cleaning

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import re

# %%
df = pd.read_csv('us_perm_visas.csv')

# %%
list(df.columns)
# Out:
# ['add_these_pw_job_title_9089',
#  'agent_city',
#  'agent_firm_name',
#  'agent_state',
#  'application_type',
#  'case_no',
#  'case_number',
#  'case_received_date',
#  'case_status',
#  'class_of_admission',
#  'country_of_citizenship',
#  'country_of_citzenship',
#  'decision_date',
#  'employer_address_1',
#  'employer_address_2',
#  'employer_city',
#  'employer_country',
#  'employer_decl_info_title',
#  'employer_name',
#  'employer_num_employees',
#  'employer_phone',
#  'employer_phone_ext',
#  'employer_postal_code',
#  'employer_state',
#  'employer_yr_estab',
#  'foreign_worker_info_alt_edu_experience',
#  'foreign_worker_info_birth_country',
#  'foreign_worker_info_city',
#  'foreign_worker_info_education',
#  'foreign_worker_info_education_other',
#  'foreign_worker_info_inst',
#  'foreign_worker_info_major',
#  'foreign_worker_info_postal_code',
#  'foreign_worker_info_rel_occup_exp',
#  'foreign_worker_info_req_experience',
#  'foreign_worker_info_state',
# ...

# %%
df.country_of_citizenship = df.country_of_citizenship.fillna('')
df.country_of_citzenship = df.country_of_citzenship.fillna('')

# %%
df['citizenship'] = df.country_of_citizenship.astype(str)+df.country_of_citzenship.astype(str)

# %%
df['citizenship'].isna().value_counts()
# Out:
# False    374362
# Name: citizenship, dtype: int64

# %%
df.drop(columns=['country_of_citizenship','country_of_citzenship'], inplace=True)

# %%
df.drop(columns=['add_these_pw_job_title_9089','agent_city','agent_firm_name','agent_state'], inplace=True)

# %%
df.case_no = df.case_no.fillna('')
df.case_number = df.case_number.fillna('')

# %%
df['case_num'] = df.case_no.astype(str) + df.case_number.astype(str)

# %%
df['case_num'].isna().value_counts()
# Out:
# False    374362
# Name: case_num, dtype: int64

# %%
df.drop(columns=['case_no','case_number'], inplace=True)

# %%
def combine_columns(new_column_name, column1, column2):
    column1 = column1.fillna('')
    column2 = column2.fillna('')
    df[new_column_name] = column1.astype(str) + column2.astype(str)   
   
    return df.head()

# %%
combine_columns('foreign_work_alt_edu', df.foreign_worker_info_alt_edu_experience, df.fw_info_alt_edu_experience)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...     us_economic_sector  \
# ...

# %%
df.drop(columns=['foreign_worker_info_alt_edu_experience','fw_info_alt_edu_experience'], inplace=True)

# %%
combine_columns('foreign_worker_birth_country', df.foreign_worker_info_birth_country, df.fw_info_birth_country)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ... wage_offer_from_9089  \
# ...

# %%
df.drop(columns=['foreign_worker_info_birth_country','fw_info_birth_country'], inplace=True)

# %%
combine_columns('foreign_worker_edu_other', df.foreign_worker_info_education_other, df.fw_info_education_other)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ... wage_offer_to_9089  \
# ...

# %%
df.drop(columns=['foreign_worker_info_education_other', 'fw_info_education_other'], inplace=True)

# %%
combine_columns('foreign_worker_rel_occ_exp', df.foreign_worker_info_rel_occup_exp, df.fw_info_rel_occup_exp)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ... wage_offer_unit_of_pay_9089  \
# ...

# %%
df.drop(columns=['foreign_worker_info_rel_occup_exp', 'fw_info_rel_occup_exp'], inplace=True)

# %%
combine_columns('foreign_worker_req_exp',  df.foreign_worker_info_req_experience, df.fw_info_req_experience)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ... wage_offered_from_9089  \
# ...

# %%
df.drop(columns=['foreign_worker_info_req_experience', 'fw_info_req_experience'],inplace=True)

# %%
combine_columns('naics_code_2007', df.naics_us_code_2007,df.naics_2007_us_code)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ... wage_offered_to_9089  \
# ...

# %%
df.drop(columns=['naics_us_code_2007','naics_2007_us_code'],inplace=True)

# %%
combine_columns('naics_codes', df.naics_code, df.naics_us_code)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...  \
# ...

# %%
df.drop(columns=['naics_code','naics_us_code'], inplace=True)

# %%
combine_columns('naics_num', df.naics_codes, df.naics_code_2007)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...  citizenship       case_num  \
# ...

# %%
df.drop(columns=['naics_codes', 'naics_code_2007'], inplace=True)

# %%
combine_columns('naics_2007', df.naics_2007_us_title, df.naics_us_title_2007)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...  \
# ...

# %%
df.drop(columns=['naics_2007_us_title','naics_us_title_2007'], inplace=True)

# %%
combine_columns('naics_t', df.naics_title, df.naics_us_title)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...  citizenship       case_num  \
# ...

# %%
df.drop(columns=['naics_title', 'naics_us_title'], inplace=True)

# %%
combine_columns('naics_title', df.naics_t, df.naics_2007)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...       case_num  \
# ...

# %%
df.drop(columns=['naics_t', 'naics_2007'],inplace=True)

# %%
combine_columns('wage_offer_from',df.wage_offer_from_9089,df.wage_offered_from_9089)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...  citizenship       case_num  \
# ...

# %%
df.drop(columns=['wage_offer_from_9089','wage_offered_from_9089'],inplace=True)

# %%
combine_columns('wage_offer_to',df.wage_offer_to_9089,df.wage_offered_to_9089)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ...       case_num  \
# ...

# %%
df.drop(columns=['wage_offer_to_9089','wage_offered_to_9089'], inplace=True)

# %%
combine_columns('wage_unit_of_pay_offer',df.wage_offer_unit_of_pay_9089,df.wage_offered_unit_of_pay_9089)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date          employer_address_1 employer_address_2 employer_city  \
# 0    2012-02-01           24 WEST 25 STREET          5TH FLOOR      NEW YORK
# 1    2011-12-21            200 BROAD STREET                NaN     CARLSTADT
# 2    2011-12-01  1054 TECHNOLOGY PARK DRIVE                NaN    GLEN ALLEN
# 3    2011-12-01     33-17 PRINCE ST. 2ND FL                NaN      FLUSHING
# 4    2012-01-26               1373 BROADWAY                NaN        ALBANY
#
#   employer_country employer_decl_info_title  ... foreign_work_alt_edu  \
# ...

# %%
df.drop(columns=['wage_offer_unit_of_pay_9089', 'wage_offered_unit_of_pay_9089'],inplace=True)

# %%
list(df.columns)
# Out:
# ['application_type',
#  'case_received_date',
#  'case_status',
#  'class_of_admission',
#  'decision_date',
#  'employer_address_1',
#  'employer_address_2',
#  'employer_city',
#  'employer_country',
#  'employer_decl_info_title',
#  'employer_name',
#  'employer_num_employees',
#  'employer_phone',
#  'employer_phone_ext',
#  'employer_postal_code',
#  'employer_state',
#  'employer_yr_estab',
#  'foreign_worker_info_city',
#  'foreign_worker_info_education',
#  'foreign_worker_info_inst',
#  'foreign_worker_info_major',
#  'foreign_worker_info_postal_code',
#  'foreign_worker_info_state',
#  'foreign_worker_info_training_comp',
#  'foreign_worker_ownership_interest',
#  'foreign_worker_yr_rel_edu_completed',
#  'fw_info_postal_code',
#  'fw_info_training_comp',
#  'fw_info_yr_rel_edu_completed',
#  'fw_ownership_interest',
#  'ji_foreign_worker_live_on_premises',
#  'ji_fw_live_on_premises',
#  'ji_live_in_dom_svc_contract',
#  'ji_live_in_domestic_service',
# ...

# %%
df.drop(columns=['employer_address_1',
 'employer_address_2',
'employer_decl_info_title',
'employer_phone',
 'employer_phone_ext',
 'employer_postal_code',
'employer_yr_estab',
'foreign_worker_info_training_comp',
 'foreign_worker_ownership_interest',
    'foreign_worker_yr_rel_edu_completed',
    'fw_info_postal_code',
 'fw_info_training_comp',
 'fw_info_yr_rel_edu_completed',
 'fw_ownership_interest',
'ji_foreign_worker_live_on_premises',
 'ji_fw_live_on_premises',
 'ji_live_in_dom_svc_contract',
 'ji_live_in_domestic_service',
 'ji_offered_to_sec_j_foreign_worker',
 'ji_offered_to_sec_j_fw',
 'job_info_alt_cmb_ed_oth_yrs',
 'job_info_alt_combo_ed',
 'job_info_alt_combo_ed_exp',
 'job_info_alt_combo_ed_other',
 'job_info_alt_field',
 'job_info_alt_field_name',
    'job_info_alt_occ',
 'job_info_alt_occ_job_title',
 'job_info_alt_occ_num_months',
 'job_info_combo_occupation',
 'job_info_education',
 'job_info_education_other',
 'job_info_experience',
 'job_info_experience_num_months',
 'job_info_foreign_ed',
 'job_info_foreign_lang_req',
 'job_info_job_req_normal',
 'job_info_job_title',
 'job_info_major',
 'job_info_training',
 'job_info_training_field',
 'job_info_training_num_months',
     'job_info_work_city',
 'job_info_work_postal_code',
 'job_info_work_state',
    'preparer_info_emp_completed',
 'preparer_info_title',
 'pw_determ_date',
 'pw_expire_date',
'pw_source_name_9089',
 'pw_source_name_other_9089',
 'pw_track_num',
 'pw_unit_of_pay_9089',
 'rec_info_barg_rep_notified',
 'recr_info_barg_rep_notified',
 'recr_info_coll_teach_comp_proc',
 'recr_info_coll_univ_teacher',
 'recr_info_employer_rec_payment',
 'recr_info_first_ad_start',
 'recr_info_job_fair_from',
 'recr_info_job_fair_to',
 'recr_info_on_campus_recr_from',
 'recr_info_on_campus_recr_to',
 'recr_info_pro_org_advert_from',
 'recr_info_pro_org_advert_to',
 'recr_info_prof_org_advert_from',
 'recr_info_prof_org_advert_to',
 'recr_info_professional_occ',
 'recr_info_radio_tv_ad_from',
 'recr_info_radio_tv_ad_to',
 'recr_info_second_ad_start',
 'recr_info_sunday_newspaper',
 'recr_info_swa_job_order_end',
 'recr_info_swa_job_order_start',
 'ri_1st_ad_newspaper_name',
 'ri_2nd_ad_newspaper_name',
 'ri_2nd_ad_newspaper_or_journal',
 'ri_campus_placement_from',
 'ri_campus_placement_to',
 'ri_coll_tch_basic_process',
 'ri_coll_teach_pro_jnl',
 'ri_coll_teach_select_date',
 'ri_employee_referral_prog_from',
 'ri_employee_referral_prog_to',
 'ri_employer_web_post_from',
 'ri_employer_web_post_to',
 'ri_job_search_website_from',
 'ri_job_search_website_to',
 'ri_layoff_in_past_six_months',
 'ri_local_ethnic_paper_from',
 'ri_local_ethnic_paper_to',
 'ri_posted_notice_at_worksite',
 'ri_pvt_employment_firm_from',
 'ri_pvt_employment_firm_to',
 'ri_us_workers_considered',
 'schd_a_sheepherder','foreign_worker_info_inst','foreign_worker_info_major','foreign_worker_info_postal_code', 'orig_case_no','orig_file_date'],inplace=True)

# %%
df.head(2)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
#
#   decision_date employer_city employer_country                employer_name  \
# 0    2012-02-01      NEW YORK              NaN             NETSOFT USA INC.
# 1    2011-12-21     CARLSTADT              NaN  PINNACLE ENVIRONEMNTAL CORP
#
#    employer_num_employees employer_state  ... foreign_work_alt_edu  \
# 0                     NaN             NY  ...
# 1                     NaN             NY  ...
#
#   foreign_worker_birth_country foreign_worker_edu_other  \
# 0
# 1
#
#   foreign_worker_rel_occ_exp foreign_worker_req_exp naics_num  \
# 0                                                      541512
# 1                                                      562211
#
#                               naics_title wage_offer_from wage_offer_to  \
# ...

# %%
combine_columns('pw_job_title', df.pw_job_title_908, df.pw_job_title_9089)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
# 2             PERM                NaN   Certified               H-1B
# 3             PERM                NaN   Certified                B-2
# 4             PERM                NaN   Certified                L-1
#
#   decision_date employer_city employer_country                employer_name  \
# 0    2012-02-01      NEW YORK              NaN             NETSOFT USA INC.
# 1    2011-12-21     CARLSTADT              NaN  PINNACLE ENVIRONEMNTAL CORP
# 2    2011-12-01    GLEN ALLEN              NaN   SCHNABEL ENGINEERING, INC.
# 3    2011-12-01      FLUSHING              NaN      EBENEZER MISSION CHURCH
# 4    2012-01-26        ALBANY              NaN   ALBANY INTERNATIONAL CORP.
#
#    employer_num_employees employer_state  ... foreign_worker_birth_country  \
# ...

# %%
list(df.columns)
# Out:
# ['application_type',
#  'case_received_date',
#  'case_status',
#  'class_of_admission',
#  'decision_date',
#  'employer_city',
#  'employer_country',
#  'employer_name',
#  'employer_num_employees',
#  'employer_state',
#  'foreign_worker_info_city',
#  'foreign_worker_info_education',
#  'foreign_worker_info_state',
#  'pw_amount_9089',
#  'pw_job_title_908',
#  'pw_job_title_9089',
#  'pw_level_9089',
#  'pw_soc_code',
#  'pw_soc_title',
#  'refile',
#  'us_economic_sector',
#  'citizenship',
#  'case_num',
#  'foreign_work_alt_edu',
#  'foreign_worker_birth_country',
#  'foreign_worker_edu_other',
#  'foreign_worker_rel_occ_exp',
#  'foreign_worker_req_exp',
#  'naics_num',
#  'naics_title',
#  'wage_offer_from',
#  'wage_offer_to',
#  'wage_unit_of_pay_offer',
#  'pw_job_title']

# %%
df.drop(columns=['pw_job_title_908', 'pw_job_title_9089','employer_country'], inplace=True)

# %%
df.count()
# Out:
# application_type                 135269
# case_received_date               239091
# case_status                      374362
# class_of_admission               351517
# decision_date                    374362
# employer_city                    374348
# employer_name                    374350
# employer_num_employees           239013
# employer_state                   374320
# foreign_worker_info_city         239065
# foreign_worker_info_education    239053
# foreign_worker_info_state        221898
# pw_amount_9089                   372146
# pw_level_9089                    346735
# pw_soc_code                      373965
# pw_soc_title                     372026
# refile                           118079
# us_economic_sector               129068
# citizenship                      374362
# case_num                         374362
# foreign_work_alt_edu             374362
# foreign_worker_birth_country     374362
# foreign_worker_edu_other         374362
# ...

# %%
df.head(2)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
# 1             PERM                NaN      Denied                B-2
#
#   decision_date employer_city                employer_name  \
# 0    2012-02-01      NEW YORK             NETSOFT USA INC.
# 1    2011-12-21     CARLSTADT  PINNACLE ENVIRONEMNTAL CORP
#
#    employer_num_employees employer_state foreign_worker_info_city  ...  \
# 0                     NaN             NY                      NaN  ...
# 1                     NaN             NY                      NaN  ...
#
#   foreign_worker_birth_country foreign_worker_edu_other  \
# 0
# 1
#
#   foreign_worker_rel_occ_exp foreign_worker_req_exp naics_num  \
# 0                                                      541512
# 1                                                      562211
#
#                               naics_title wage_offer_from wage_offer_to  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Data columns (total 31 columns):
# application_type                 135269 non-null object
# case_received_date               239091 non-null object
# case_status                      374362 non-null object
# class_of_admission               351517 non-null object
# decision_date                    374362 non-null object
# employer_city                    374348 non-null object
# employer_name                    374350 non-null object
# employer_num_employees           239013 non-null float64
# employer_state                   374320 non-null object
# foreign_worker_info_city         239065 non-null object
# foreign_worker_info_education    239053 non-null object
# foreign_worker_info_state        221898 non-null object
# pw_amount_9089                   372146 non-null object
# pw_level_9089                    346735 non-null object
# pw_soc_code                      373965 non-null object
# ...

# %%
df.employer_city = df.employer_city.str.upper()

# %%
df.employer_name = df.employer_name.str.upper()

# %%
df.naics_title = df.naics_title.str.upper()

# %%
df.pw_job_title = df.pw_job_title.str.upper()

# %%
df.us_economic_sector = df.us_economic_sector.str.upper()

# %%
df.pw_soc_title  = df.pw_soc_title.str.upper()

# %%
df.head(1)
# Out:
#   application_type case_received_date case_status class_of_admission  \
# 0             PERM                NaN   Certified                J-1
#
#   decision_date employer_city     employer_name  employer_num_employees  \
# 0    2012-02-01      NEW YORK  NETSOFT USA INC.                     NaN
#
#   employer_state foreign_worker_info_city  ... foreign_worker_birth_country  \
# 0             NY                      NaN  ...
#
#   foreign_worker_edu_other foreign_worker_rel_occ_exp foreign_worker_req_exp  \
# 0
#
#   naics_num                       naics_title wage_offer_from wage_offer_to  \
# 0    541512  COMPUTER SYSTEMS DESIGN SERVICES         75629.0
#
#   wage_unit_of_pay_offer                               pw_job_title
# 0                     yr  COMPUTER SOFTWARE ENGINEERS, APPLICATIONS
#
# [1 rows x 31 columns]

# %%
df['wage_unit_of_pay_offer'] = df['wage_unit_of_pay_offer'].replace('bi',"Bi-Weekly")

# %%
df['wage_unit_of_pay_offer'] = df['wage_unit_of_pay_offer'].replace('mth',"Month")

# %%
df['wage_unit_of_pay_offer'] = df['wage_unit_of_pay_offer'].replace('wk',"Week")

# %%
df['wage_unit_of_pay_offer'] = df['wage_unit_of_pay_offer'].replace('hr',"Hour")

# %%
df['wage_unit_of_pay_offer'] = df['wage_unit_of_pay_offer'].replace('yr',"Year")

# %%
df = df.replace("",np.NaN)

# %%
df.to_csv(r'~/Code/mod_3_project/visa_clean.csv')
